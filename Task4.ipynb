# %%
#Task  - Superstore_USA data
1 . Load this data in sql and in pandas with a relation in sql 
2 . While loading this data you dont have to create a table manually. You can use any automated approach to create a table and load a data in bulk in table 
3 . Find out how return that we ahve recived and with a product id 
4 . try  to join order and return data both in sql and pandas 
5 . Try to find out how many unique customer that we have 
6 . try to find out in how many regions we are selling a product and who is a manager for a respective region 
7 . find out how many different differnet shipement mode that we have and what is a percentage usablity of all the shipment mode with respect to dataset 
8 . Create a new coulmn and try to find our a diffrence between order date and shipment date
9 . base on question number 8 find out for which order id we have shipment duration more than 10 days 
10 . Try to find out a list of a returned order which sihpment duration was more then 15 days and find out that region manager as well 
11 . Gorup by region and find out which region is more profitable 
12 . Try to find out overalll in which country we are giving more didscount 
13 . Give me a list of unique postal code 
14 . which customer segement is more profitalble find it out . 
15 . try to find out the 10th most loss making product catagory . 
16 . Try to find out 10 top  product with highest margins

# %%
import pandas as pd
from sqlalchemy import engine as sa
import xlrd

# %%
pip install openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Value for scheme.headers does not match. Please report this to <https://github.com/pypa/pip/issues/9617>
# distutils: c:\users\shwetanksingh\appdata\local\programs\python\python39\Include\UNKNOWN
# sysconfig: c:\users\shwetanksingh\appdata\local\programs\python\python39\Include
# WARNING: Additional context:
# user = False
# home = None
# root = None
# prefix = None
# WARNING: Value for scheme.headers does not match. Please report this to <https://github.com/pypa/pip/issues/9617>
# distutils: c:\users\shwetanksingh\appdata\local\programs\python\python39\Include\UNKNOWN
# sysconfig: c:\users\shwetanksingh\appdata\local\programs\python\python39\Include
# WARNING: Additional context:
# user = False
# home = None
# root = None
# prefix = None
# WARNING: You are using pip version 21.1; however, version 22.2.2 is available.
# ...

# %%
# Q1

# %%
df=pd.read_excel(r"C:\Academics\INEURON\others\Superstore_USA.xlsx")

# %%
df
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0      18606  Not Specified      0.01        2.88           0.50            2
# 1      20847           High      0.01        2.84           0.93            3
# 2      23086  Not Specified      0.03        6.68           6.15            3
# 3      23087  Not Specified      0.01        5.68           3.60            3
# 4      23088  Not Specified      0.00      205.99           2.50            3
# ...      ...            ...       ...         ...            ...          ...
# 9421   20275       Critical      0.06       35.89          14.72         3402
# 9422   20276       Critical      0.00        3.34           7.49         3402
# 9423   24491  Not Specified      0.08      550.98          45.70         3402
# 9424   25914           High      0.10      105.98          13.99         3403
# 9425   24492  Not Specified      0.09        7.78           2.50         3403
#
# ...

# %%
df1 = pd.read_excel(r"C:\Academics\INEURON\others\Superstore_USA.xlsx",sheet_name=1)
df1
# Out:
#       Order ID    Status
# 0           65  Returned
# 1          612  Returned
# 2          614  Returned
# 3          678  Returned
# 4          710  Returned
# ...        ...       ...
# 1629    182681  Returned
# 1630    182683  Returned
# 1631    182750  Returned
# 1632    182781  Returned
# 1633    182906  Returned
#
# [1634 rows x 2 columns]

# %%
df2 = pd.read_excel(r"C:\Academics\INEURON\others\Superstore_USA.xlsx",sheet_name=2)
df2
# Out:
#     Region  Manager
# 0  Central    Chris
# 1     East     Erin
# 2    South      Sam
# 3     West  William

# %%
# Connect to MySQL
import mysql.connector as conn

mydb = conn.connect(host ="localhost" , user = "root" , passwd = "mysql123")
cursor = mydb.cursor()
cursor.execute("create database if not exists USA_Data")

# %%
# Q2

# %%
# Read this dataset in MySQL
engine = sa.create_engine('mysql://root:mysql123@localhost:3306/USA_Data')

# %%
df.to_sql(name='USA_table',con=engine)
# Out:
# c:\users\shwetanksingh\appdata\local\programs\python\python39\lib\site-packages\pandas\io\sql.py:1444: UserWarning: The provided table name 'USA_table' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   warnings.warn(msg, UserWarning)

# %%
cursor.execute("use USA_Data")

# %%
data = pd.read_sql_query("select * from USA_table ",engine)
data
# Out:
#       index  Row ID Order Priority  Discount  Unit Price  Shipping Cost  \
# 0         0   18606  Not Specified      0.01        2.88           0.50
# 1         1   20847           High      0.01        2.84           0.93
# 2         2   23086  Not Specified      0.03        6.68           6.15
# 3         3   23087  Not Specified      0.01        5.68           3.60
# 4         4   23088  Not Specified      0.00      205.99           2.50
# ...     ...     ...            ...       ...         ...            ...
# 9421   9421   20275       Critical      0.06       35.89          14.72
# 9422   9422   20276       Critical      0.00        3.34           7.49
# 9423   9423   24491  Not Specified      0.08      550.98          45.70
# 9424   9424   25914           High      0.10      105.98          13.99
# 9425   9425   24492  Not Specified      0.09        7.78           2.50
#
#       Customer ID    Customer Name       Ship Mode Customer Segment  ...  \
# ...

# %%
# Q3

# %%
merged_data=pd.merge(df,df1,on='Order ID')
merged_data
# Out:
#     Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0     1359            Low      0.05        5.85           2.27           21
# 1     1950         Medium      0.01        4.91           0.50          117
# 2     1951         Medium      0.09        4.00           1.30          117
# 3     5055           High      0.02        3.28           5.00          117
# 4     5573            Low      0.02       11.97           5.81          272
# ..     ...            ...       ...         ...            ...          ...
# 93     986  Not Specified      0.06       37.94           5.08         3075
# 94     987  Not Specified      0.10       55.29           5.08         3075
# 95    6041         Medium      0.05        4.28           6.18         3075
# 96    1910           High      0.05       14.48           1.99         3079
# 97    6625           High      0.06      128.24          12.65         3251
#
# ...

# %%
merged_data.dtypes
# Out:
# Row ID                           int64
# Order Priority                  object
# Discount                       float64
# Unit Price                     float64
# Shipping Cost                  float64
# Customer ID                      int64
# Customer Name                   object
# Ship Mode                       object
# Customer Segment                object
# Product Category                object
# Product Sub-Category            object
# Product Container               object
# Product Name                    object
# Product Base Margin            float64
# Region                          object
# State or Province               object
# City                            object
# Postal Code                      int64
# Order Date              datetime64[ns]
# Ship Date               datetime64[ns]
# Profit                         float64
# Quantity ordered new             int64
# Sales                          float64
# Order ID                         int64
# ...

# %%
merged_data.columns
# Out:
# Index(['Row ID', 'Order Priority', 'Discount', 'Unit Price', 'Shipping Cost',
#        'Customer ID', 'Customer Name', 'Ship Mode', 'Customer Segment',
#        'Product Category', 'Product Sub-Category', 'Product Container',
#        'Product Name', 'Product Base Margin', 'Region', 'State or Province',
#        'City', 'Postal Code', 'Order Date', 'Ship Date', 'Profit',
#        'Quantity ordered new', 'Sales', 'Order ID', 'Status'],
#       dtype='object')

# %%
len(merged_data['Status']=='Returned')
# Out:
# 98

# %%
#Q4

# %%
order_return =pd.merge(df , df1)
order_return
# Out:
#     Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0     1359            Low      0.05        5.85           2.27           21
# 1     1950         Medium      0.01        4.91           0.50          117
# 2     1951         Medium      0.09        4.00           1.30          117
# 3     5055           High      0.02        3.28           5.00          117
# 4     5573            Low      0.02       11.97           5.81          272
# ..     ...            ...       ...         ...            ...          ...
# 93     986  Not Specified      0.06       37.94           5.08         3075
# 94     987  Not Specified      0.10       55.29           5.08         3075
# 95    6041         Medium      0.05        4.28           6.18         3075
# 96    1910           High      0.05       14.48           1.99         3079
# 97    6625           High      0.06      128.24          12.65         3251
#
# ...

# %%
#Q5

# %%
df.head(2)
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0   18606  Not Specified      0.01        2.88           0.50            2
# 1   20847           High      0.01        2.84           0.93            3
#
#      Customer Name    Ship Mode Customer Segment Product Category  ...  \
# 0  Janice Fletcher  Regular Air        Corporate  Office Supplies  ...
# 1    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
#
#     Region State or Province       City  Postal Code Order Date  Ship Date  \
# 0  Central          Illinois    Addison        60101 2012-05-28 2012-05-30
# 1     West        Washington  Anacortes        98221 2010-07-07 2010-07-08
#
#   Profit  Quantity ordered new  Sales Order ID
# 0   1.32                     2   5.90    88525
# 1   4.56                     4  13.01    88522
#
# [2 rows x 24 columns]

# %%
df['Customer ID'].nunique()
# Out:
# 2703

# %%
# Q6

# %%
df['Region'].unique()
# Out:
# array(['Central', 'West', 'East', 'South'], dtype=object)

# %%
df['Region'].nunique()
# Out:
# 4

# %%
df2
# Out:
#     Region  Manager
# 0  Central    Chris
# 1     East     Erin
# 2    South      Sam
# 3     West  William

# %%
# Q7

# %%
df['Ship Mode'].unique()
# Out:
# array(['Regular Air', 'Express Air', 'Delivery Truck'], dtype=object)

# %%
df['Ship Mode'].nunique()
# Out:
# 3

# %%
df.shape
# Out:
# (9426, 24)

# %%
ans7=pd.DataFrame(df['Ship Mode'].value_counts())
ans7
# Out:
#                 Ship Mode
# Regular Air          7036
# Delivery Truck       1283
# Express Air          1107

# %%
ans7['SegmentUtilization']=(ans7['Ship Mode']/9426)*100

# %%
ans7
# Out:
#                 Ship Mode  SegmentUtilization
# Regular Air          7036           74.644600
# Delivery Truck       1283           13.611288
# Express Air          1107           11.744112

# %%
# Q8

# %%
df.head(2)
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0   18606  Not Specified      0.01        2.88           0.50            2
# 1   20847           High      0.01        2.84           0.93            3
#
#      Customer Name    Ship Mode Customer Segment Product Category  ...  \
# 0  Janice Fletcher  Regular Air        Corporate  Office Supplies  ...
# 1    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
#
#     Region State or Province       City  Postal Code Order Date  Ship Date  \
# 0  Central          Illinois    Addison        60101 2012-05-28 2012-05-30
# 1     West        Washington  Anacortes        98221 2010-07-07 2010-07-08
#
#   Profit  Quantity ordered new  Sales Order ID
# 0   1.32                     2   5.90    88525
# 1   4.56                     4  13.01    88522
#
# [2 rows x 24 columns]

# %%
df.dtypes
# Out:
# Row ID                           int64
# Order Priority                  object
# Discount                       float64
# Unit Price                     float64
# Shipping Cost                  float64
# Customer ID                      int64
# Customer Name                   object
# Ship Mode                       object
# Customer Segment                object
# Product Category                object
# Product Sub-Category            object
# Product Container               object
# Product Name                    object
# Product Base Margin            float64
# Region                          object
# State or Province               object
# City                            object
# Postal Code                      int64
# Order Date              datetime64[ns]
# Ship Date               datetime64[ns]
# Profit                         float64
# Quantity ordered new             int64
# Sales                          float64
# Order ID                         int64
# dtype: object

# %%
df['order_ship_date_diff']=df['Ship Date']-df['Order Date']

# %%
merged_data['order_ship_date_diff']=merged_data['Ship Date']-merged_data['Order Date']

# %%
df[['order_ship_date_diff']]
# Out:
#      order_ship_date_diff
# 0                  2 days
# 1                  1 days
# 2                  1 days
# 3                  1 days
# 4                  0 days
# ...                   ...
# 9421               1 days
# 9422               0 days
# 9423               2 days
# 9424               3 days
# 9425               2 days
#
# [9426 rows x 1 columns]

# %%
#Q9

# %%
df[df['order_ship_date_diff']>'10 days']['Order ID']
# Out:
# 643     87215
# 1548    86318
# 1549    86318
# 1678    87957
# 1679    87957
# 1680    87957
# 1697    19556
# 1698    19556
# 1699    19556
# 2515    86177
# 5548    88223
# 5673    88352
# 5859    87572
# 5881    91294
# 8607    86434
# 8609    86436
# 8610    86436
# 8973    87300
# 8982    19841
# 8983    19841
# 8993    19841
# 8996    87300
# 8997    87300
# Name: Order ID, dtype: int64

# %%
# Q10

# %%
ans9=pd.merge(df,df2)
ans9.head(1)
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0   18606  Not Specified      0.01        2.88            0.5            2
#
#      Customer Name    Ship Mode Customer Segment Product Category  ...  \
# 0  Janice Fletcher  Regular Air        Corporate  Office Supplies  ...
#
#       City Postal Code Order Date  Ship Date Profit Quantity ordered new  \
# 0  Addison       60101 2012-05-28 2012-05-30   1.32                    2
#
#   Sales  Order ID order_ship_date_diff Manager
# 0   5.9     88525               2 days   Chris
#
# [1 rows x 26 columns]

# %%
ans=pd.merge(ans9,df1)

# %%
df5 = pd.DataFrame(ans[ans['order_ship_date_diff'] > "15 days"]['Manager'])
df5

# %%
#Q11

# %%
ans9.groupby('Region')['Profit'].sum()
# Out:
# Region
# Central    519825.567067
# East       377566.186045
# South      104201.192420
# West       310849.453897
# Name: Profit, dtype: float64

# %%
#Q12

# %%
df7 = pd.DataFrame(ans9.groupby('City')['Discount'].sum())
df7
# Out:
#             Discount
# City
# Aberdeen        0.32
# Abilene         0.22
# Abington        0.08
# Acton           0.00
# Addison         0.23
# ...              ...
# York            0.21
# Youngstown      0.33
# Yuba City       0.01
# Yucaipa         0.15
# Yuma            0.18
#
# [1424 rows x 1 columns]

# %%
#Q13

# %%
df7['Rank'] = df7['Discount'].rank(method = 'max', ascending = False)

# %%
df7[df7['Rank']== 1]
# Out:
#              Discount  Rank
# City
# Los Angeles     10.37   1.0

# %%
#Q13

# %%
df8 = (ans9['Postal Code'].unique())
df8
# Out:
# array([60101, 55372, 68005, ..., 30144, 30240, 31204], dtype=int64)

# %%
#Q14

# %%
df9 = pd.DataFrame(ans9.groupby('Customer Segment')['Profit'].sum())
df9
# Out:
#                          Profit
# Customer Segment
# Consumer          206559.625348
# Corporate         505538.627783
# Home Office       283869.553814
# Small Business    316474.592482

# %%
df9.sort_values(ascending=False,by='Profit')
# Out:
#                          Profit
# Customer Segment
# Corporate         505538.627783
# Small Business    316474.592482
# Home Office       283869.553814
# Consumer          206559.625348

# %%
#Q15

# %%
df.head(2)
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0   18606  Not Specified      0.01        2.88           0.50            2
# 1   20847           High      0.01        2.84           0.93            3
#
#      Customer Name    Ship Mode Customer Segment Product Category  ...  \
# 0  Janice Fletcher  Regular Air        Corporate  Office Supplies  ...
# 1    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
#
#   State or Province       City Postal Code  Order Date  Ship Date Profit  \
# 0          Illinois    Addison       60101  2012-05-28 2012-05-30   1.32
# 1        Washington  Anacortes       98221  2010-07-07 2010-07-08   4.56
#
#   Quantity ordered new  Sales Order ID order_ship_date_diff
# 0                    2   5.90    88525               2 days
# 1                    4  13.01    88522               1 days
#
# [2 rows x 25 columns]

# %%
df['Product Category'].value_counts()
# Out:
# Office Supplies    5181
# Technology         2312
# Furniture          1933
# Name: Product Category, dtype: int64

# %%
df10 =pd.DataFrame(df.groupby('Product Name')['Profit'].sum())
df10
# Out:
#                                                          Profit
# Product Name
# "While you Were Out" Message Book, One Form per...   708.820800
# #10 Self-Seal White Envelopes                        223.197520
# #10 White Business Envelopes,4 1/8 x 9 1/2          1164.001460
# #10- 4 1/8" x 9 1/2" Recycled Envelopes             -888.757800
# #10- 4 1/8" x 9 1/2" Security-Tint Envelopes       -1288.400800
# ...                                                         ...
# i500plus                                             808.244640
# i600                                                -525.934816
# iDEN i550                                           2624.076000
# iDEN i95                                            -371.274704
# iDENi80s                                            -471.229440
#
# [1263 rows x 1 columns]

# %%
df10['Rank'] = df10['Profit'].rank(method = 'max',ascending=True)

# %%
df10[df10['Rank'] == 10]
# Out:
#                                                        Profit  Rank
# Product Name
# Eldon ClusterMat Chair Mat with Cordless Antist... -9543.6525  10.0

# %%
#Q16

# %%
df.sort_values(['Product Base Margin'],ascending=False)['Product Name'].head(10)
# Out:
# 9145                                          Accessory27
# 4756                                           Accessory4
# 7607                                          Accessory27
# 5672                                           Accessory4
# 4168                    Sterling Rubber Bands by Alliance
# 807                                           Accessory27
# 816                                           Accessory27
# 3994    Office Impressions Heavy Duty Welded Shelving ...
# 2138                    Sterling Rubber Bands by Alliance
# 7202    Office Impressions Heavy Duty Welded Shelving ...
# Name: Product Name, dtype: object
